# %% [markdown]
# ### Autor: Johnny Rubio Pecasso
# ### Fecha: 04/sep/2024
# ### Introduccion a la ciencia de datos
# ### Notebook 04.09-Text-and-Annotation

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib as mpl
plt.style.use('seaborn-whitegrid')
import numpy as np
import pandas as pd

# %%
births = pd.read_csv('data/births.csv')

quartiles = np.percentile(births['births'], [25, 50, 75])
mu, sig = quartiles[1], 0.74 * (quartiles[2] - quartiles[0])
births = births.query('(births > @mu - 5 * @sig) & (births < @mu + 5 * @sig)')

births['day'] = births['day'].astype(int)

births.index = pd.to_datetime(10000 * births.year +
                              100 * births.month +
                              births.day, format='%Y%m%d')
births_by_date = births.pivot_table('births',
                                    [births.index.month, births.index.day])
births_by_date.index = [pd.datetime(2012, month, day)
                        for (month, day) in births_by_date.index]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 14
#       9 births.index = pd.to_datetime(10000 * births.year +
#      10                               100 * births.month +
#      11                               births.day, format='%Y%m%d')
#      12 births_by_date = births.pivot_table('births',
#      13                                     [births.index.month, births.index.day])
# ---> 14 births_by_date.index = [pd.datetime(2012, month, day)
#      15                         for (month, day) in births_by_date.index]
#
# Cell In[2], line 14, in <listcomp>(.0)
#       9 births.index = pd.to_datetime(10000 * births.year +
#      10                               100 * births.month +
#      11                               births.day, format='%Y%m%d')
#      12 births_by_date = births.pivot_table('births',
#      13                                     [births.index.month, births.index.day])
# ---> 14 births_by_date.index = [pd.datetime(2012, month, day)
#      15                         for (month, day) in births_by_date.index]
#
# AttributeError: module 'pandas' has no attribute 'datetime'

# %%
fig, ax = plt.subplots(figsize=(12, 4))
births_by_date.plot(ax=ax);

# %%
fig, ax = plt.subplots(figsize=(12, 4))
births_by_date.plot(ax=ax)

# Add labels to the plot
style = dict(size=10, color='gray')

ax.text('2012-1-1', 3950, "New Year's Day", **style)
ax.text('2012-7-4', 4250, "Independence Day", ha='center', **style)
ax.text('2012-9-4', 4850, "Labor Day", ha='center', **style)
ax.text('2012-10-31', 4600, "Halloween", ha='right', **style)
ax.text('2012-11-25', 4450, "Thanksgiving", ha='center', **style)
ax.text('2012-12-25', 3850, "Christmas ", ha='right', **style)

# Label the axes
ax.set(title='USA births by day of year (1969-1988)',
       ylabel='average daily births')

# Format the x axis with centered month labels
ax.xaxis.set_major_locator(mpl.dates.MonthLocator())
ax.xaxis.set_minor_locator(mpl.dates.MonthLocator(bymonthday=15))
ax.xaxis.set_major_formatter(plt.NullFormatter())
ax.xaxis.set_minor_formatter(mpl.dates.DateFormatter('%h'));
# Out:
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x00000229D39AF550> (for post_execute):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\pyton38\lib\site-packages\matplotlib\axis.py:1520, in Axis.convert_units(self, x)
#    1519 try:
# -> 1520     ret = self.converter.convert(x, self.units, self)
#    1521 except Exception as e:
#
# File c:\pyton38\lib\site-packages\matplotlib\category.py:49, in StrCategoryConverter.convert(value, unit, axis)
#      48 if unit is None:
# ---> 49     raise ValueError(
#      50         'Missing category information for StrCategoryConverter; '
#      51         'this might be caused by unintendedly mixing categorical and '
#      52         'numeric data')
#      53 # dtype = object preserves numerical pass throughs
#
# ValueError: Missing category information for StrCategoryConverter; this might be caused by unintendedly mixing categorical and numeric data
#
# The above exception was the direct cause of the following exception:
#
# ConversionError                           Traceback (most recent call last)
# File c:\pyton38\lib\site-packages\matplotlib\pyplot.py:138, in install_repl_displayhook.<locals>.post_execute()
#     136 def post_execute():
#     137     if matplotlib.is_interactive():
# --> 138         draw_all()
#
# File c:\pyton38\lib\site-packages\matplotlib\_pylab_helpers.py:138, in Gcf.draw_all(cls, force)
#     136 for manager in cls.get_all_fig_managers():
#     137     if force or manager.canvas.figure.stale:
# --> 138         manager.canvas.draw_idle()
#
# File c:\pyton38\lib\site-packages\matplotlib\backend_bases.py:2012, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    2010 if not self._is_idle_drawing:
#    2011     with self._idle_draw_cntx():
# -> 2012         self.draw(*args, **kwargs)
#
# File c:\pyton38\lib\site-packages\matplotlib\backends\backend_agg.py:407, in FigureCanvasAgg.draw(self)
#     403 # Acquire a lock on the shared font cache.
#     404 with RendererAgg.lock, \
#     405      (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     406       else nullcontext()):
# --> 407     self.figure.draw(self.renderer)
#     408     # A GUI class may be need to update a window using this draw, so
#     409     # don't forget to call the superclass.
#     410     super().draw()
#
# File c:\pyton38\lib\site-packages\matplotlib\artist.py:41, in allow_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      38     if artist.get_agg_filter() is not None:
#      39         renderer.start_filter()
# ---> 41     return draw(artist, renderer, *args, **kwargs)
#      42 finally:
#      43     if artist.get_agg_filter() is not None:
#
# File c:\pyton38\lib\site-packages\matplotlib\figure.py:1863, in Figure.draw(self, renderer)
#    1860             # ValueError can occur when resizing a window.
#    1862     self.patch.draw(renderer)
# -> 1863     mimage._draw_list_compositing_images(
#    1864         renderer, self, artists, self.suppressComposite)
#    1866     renderer.close_group('figure')
#    1867 finally:
#
# File c:\pyton38\lib\site-packages\matplotlib\image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File c:\pyton38\lib\site-packages\matplotlib\artist.py:41, in allow_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      38     if artist.get_agg_filter() is not None:
#      39         renderer.start_filter()
# ---> 41     return draw(artist, renderer, *args, **kwargs)
#      42 finally:
#      43     if artist.get_agg_filter() is not None:
#
# File c:\pyton38\lib\site-packages\matplotlib\cbook\deprecation.py:411, in _delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     401     deprecation_addendum = (
#     402         f"If any parameter follows {name!r}, they should be passed as "
#     403         f"keyword, not positionally.")
#     404     warn_deprecated(
#     405         since,
#     406         name=repr(name),
#    (...)
#     409                  else deprecation_addendum,
#     410         **kwargs)
# --> 411 return func(*inner_args, **inner_kwargs)
#
# File c:\pyton38\lib\site-packages\matplotlib\axes\_base.py:2747, in _AxesBase.draw(self, renderer, inframe)
#    2744         a.draw(renderer)
#    2745     renderer.stop_rasterizing()
# -> 2747 mimage._draw_list_compositing_images(renderer, self, artists)
#    2749 renderer.close_group('axes')
#    2750 self.stale = False
#
# File c:\pyton38\lib\site-packages\matplotlib\image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File c:\pyton38\lib\site-packages\matplotlib\artist.py:41, in allow_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      38     if artist.get_agg_filter() is not None:
#      39         renderer.start_filter()
# ---> 41     return draw(artist, renderer, *args, **kwargs)
#      42 finally:
#      43     if artist.get_agg_filter() is not None:
#
# File c:\pyton38\lib\site-packages\matplotlib\text.py:679, in Text.draw(self, renderer)
#     676 renderer.open_group('text', self.get_gid())
#     678 with _wrap_text(self) as textobj:
# --> 679     bbox, info, descent = textobj._get_layout(renderer)
#     680     trans = textobj.get_transform()
#     682     # don't use textobj.get_position here, which refers to text
#     683     # position in Text:
#
# File c:\pyton38\lib\site-packages\matplotlib\text.py:272, in Text._get_layout(self, renderer)
#     266 def _get_layout(self, renderer):
#     267     """
#     268     Return the extent (bbox) of the text together with
#     269     multiple-alignment information. Note that it returns an extent
#     270     of a rotated text when necessary.
#     271     """
# --> 272     key = self.get_prop_tup(renderer=renderer)
#     273     if key in self._cached:
#     274         return self._cached[key]
#
# File c:\pyton38\lib\site-packages\matplotlib\text.py:840, in Text.get_prop_tup(self, renderer)
#     832 def get_prop_tup(self, renderer=None):
#     833     """
#     834     Return a hashable tuple of properties.
#     835
#    (...)
#     838     need to know if the text has changed.
#     839     """
# --> 840     x, y = self.get_unitless_position()
#     841     renderer = renderer or self._renderer
#     842     return (x, y, self.get_text(), self._color,
#     843             self._verticalalignment, self._horizontalalignment,
#     844             hash(self._fontproperties),
#    (...)
#     847             self._linespacing
#     848             )
#
# File c:\pyton38\lib\site-packages\matplotlib\text.py:822, in Text.get_unitless_position(self)
#     819 """Return the (x, y) unitless position of the text."""
#     820 # This will get the position with all unit information stripped away.
#     821 # This is here for convenience since it is done in several locations.
# --> 822 x = float(self.convert_xunits(self._x))
#     823 y = float(self.convert_yunits(self._y))
#     824 return x, y
#
# File c:\pyton38\lib\site-packages\matplotlib\artist.py:175, in Artist.convert_xunits(self, x)
#     173 if ax is None or ax.xaxis is None:
#     174     return x
# --> 175 return ax.xaxis.convert_units(x)
#
# File c:\pyton38\lib\site-packages\matplotlib\axis.py:1522, in Axis.convert_units(self, x)
#    1520     ret = self.converter.convert(x, self.units, self)
#    1521 except Exception as e:
# -> 1522     raise munits.ConversionError('Failed to convert value(s) to axis '
#    1523                                  f'units: {x!r}') from e
#    1524 return ret
#
# ConversionError: Failed to convert value(s) to axis units: '2012-1-1'
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\pyton38\lib\site-packages\matplotlib\axis.py:1520, in Axis.convert_units(self, x)
#    1519 try:
# -> 1520     ret = self.converter.convert(x, self.units, self)
#    1521 except Exception as e:
#
# File c:\pyton38\lib\site-packages\matplotlib\category.py:49, in StrCategoryConverter.convert(value, unit, axis)
#      48 if unit is None:
# ---> 49     raise ValueError(
#      50         'Missing category information for StrCategoryConverter; '
#      51         'this might be caused by unintendedly mixing categorical and '
#      52         'numeric data')
#      53 # dtype = object preserves numerical pass throughs
#
# ValueError: Missing category information for StrCategoryConverter; this might be caused by unintendedly mixing categorical and numeric data
#
# The above exception was the direct cause of the following exception:
#
# ConversionError                           Traceback (most recent call last)
# File c:\pyton38\lib\site-packages\IPython\core\formatters.py:340, in BaseFormatter.__call__(self, obj)
#     338     pass
#     339 else:
# --> 340     return printer(obj)
#     341 # Finally look for special method names
#     342 method = get_real_method(obj, self.print_method)
#
# File c:\pyton38\lib\site-packages\IPython\core\pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File c:\pyton38\lib\site-packages\matplotlib\backend_bases.py:2193, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2189 ctx = (renderer._draw_disabled()
#    2190        if hasattr(renderer, '_draw_disabled')
#    2191        else suppress())
#    2192 with ctx:
# -> 2193     self.figure.draw(renderer)
#    2195 bbox_inches = self.figure.get_tightbbox(
#    2196     renderer, bbox_extra_artists=bbox_extra_artists)
#    2197 if pad_inches is None:
#
# File c:\pyton38\lib\site-packages\matplotlib\artist.py:41, in allow_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      38     if artist.get_agg_filter() is not None:
#      39         renderer.start_filter()
# ---> 41     return draw(artist, renderer, *args, **kwargs)
#      42 finally:
#      43     if artist.get_agg_filter() is not None:
#
# File c:\pyton38\lib\site-packages\matplotlib\figure.py:1863, in Figure.draw(self, renderer)
#    1860             # ValueError can occur when resizing a window.
#    1862     self.patch.draw(renderer)
# -> 1863     mimage._draw_list_compositing_images(
#    1864         renderer, self, artists, self.suppressComposite)
#    1866     renderer.close_group('figure')
#    1867 finally:
#
# File c:\pyton38\lib\site-packages\matplotlib\image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File c:\pyton38\lib\site-packages\matplotlib\artist.py:41, in allow_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      38     if artist.get_agg_filter() is not None:
#      39         renderer.start_filter()
# ---> 41     return draw(artist, renderer, *args, **kwargs)
#      42 finally:
#      43     if artist.get_agg_filter() is not None:
#
# File c:\pyton38\lib\site-packages\matplotlib\cbook\deprecation.py:411, in _delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     401     deprecation_addendum = (
#     402         f"If any parameter follows {name!r}, they should be passed as "
#     403         f"keyword, not positionally.")
#     404     warn_deprecated(
#     405         since,
#     406         name=repr(name),
#    (...)
#     409                  else deprecation_addendum,
#     410         **kwargs)
# --> 411 return func(*inner_args, **inner_kwargs)
#
# File c:\pyton38\lib\site-packages\matplotlib\axes\_base.py:2747, in _AxesBase.draw(self, renderer, inframe)
#    2744         a.draw(renderer)
#    2745     renderer.stop_rasterizing()
# -> 2747 mimage._draw_list_compositing_images(renderer, self, artists)
#    2749 renderer.close_group('axes')
#    2750 self.stale = False
#
# File c:\pyton38\lib\site-packages\matplotlib\image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File c:\pyton38\lib\site-packages\matplotlib\artist.py:41, in allow_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      38     if artist.get_agg_filter() is not None:
#      39         renderer.start_filter()
# ---> 41     return draw(artist, renderer, *args, **kwargs)
#      42 finally:
#      43     if artist.get_agg_filter() is not None:
#
# File c:\pyton38\lib\site-packages\matplotlib\text.py:679, in Text.draw(self, renderer)
#     676 renderer.open_group('text', self.get_gid())
#     678 with _wrap_text(self) as textobj:
# --> 679     bbox, info, descent = textobj._get_layout(renderer)
#     680     trans = textobj.get_transform()
#     682     # don't use textobj.get_position here, which refers to text
#     683     # position in Text:
#
# File c:\pyton38\lib\site-packages\matplotlib\text.py:272, in Text._get_layout(self, renderer)
#     266 def _get_layout(self, renderer):
#     267     """
#     268     Return the extent (bbox) of the text together with
#     269     multiple-alignment information. Note that it returns an extent
#     270     of a rotated text when necessary.
#     271     """
# --> 272     key = self.get_prop_tup(renderer=renderer)
#     273     if key in self._cached:
#     274         return self._cached[key]
#
# File c:\pyton38\lib\site-packages\matplotlib\text.py:840, in Text.get_prop_tup(self, renderer)
#     832 def get_prop_tup(self, renderer=None):
#     833     """
#     834     Return a hashable tuple of properties.
#     835
#    (...)
#     838     need to know if the text has changed.
#     839     """
# --> 840     x, y = self.get_unitless_position()
#     841     renderer = renderer or self._renderer
#     842     return (x, y, self.get_text(), self._color,
#     843             self._verticalalignment, self._horizontalalignment,
#     844             hash(self._fontproperties),
#    (...)
#     847             self._linespacing
#     848             )
#
# File c:\pyton38\lib\site-packages\matplotlib\text.py:822, in Text.get_unitless_position(self)
#     819 """Return the (x, y) unitless position of the text."""
#     820 # This will get the position with all unit information stripped away.
#     821 # This is here for convenience since it is done in several locations.
# --> 822 x = float(self.convert_xunits(self._x))
#     823 y = float(self.convert_yunits(self._y))
#     824 return x, y
#
# File c:\pyton38\lib\site-packages\matplotlib\artist.py:175, in Artist.convert_xunits(self, x)
#     173 if ax is None or ax.xaxis is None:
#     174     return x
# --> 175 return ax.xaxis.convert_units(x)
#
# File c:\pyton38\lib\site-packages\matplotlib\axis.py:1522, in Axis.convert_units(self, x)
#    1520     ret = self.converter.convert(x, self.units, self)
#    1521 except Exception as e:
# -> 1522     raise munits.ConversionError('Failed to convert value(s) to axis '
#    1523                                  f'units: {x!r}') from e
#    1524 return ret
#
# ConversionError: Failed to convert value(s) to axis units: '2012-1-1'

# %%
fig, ax = plt.subplots(facecolor='lightgray')
ax.axis([0, 10, 0, 10])

# transform=ax.transData is the default, but we'll specify it anyway
ax.text(1, 5, ". Data: (1, 5)", transform=ax.transData)
ax.text(0.5, 0.1, ". Axes: (0.5, 0.1)", transform=ax.transAxes)
ax.text(0.2, 0.2, ". Figure: (0.2, 0.2)", transform=fig.transFigure);

# %%
ax.set_xlim(0, 2)
ax.set_ylim(-6, 6)
fig

# %%
# %matplotlib inline

fig, ax = plt.subplots()

x = np.linspace(0, 20, 1000)
ax.plot(x, np.cos(x))
ax.axis('equal')

ax.annotate('local maximum', xy=(6.28, 1), xytext=(10, 4),
            arrowprops=dict(facecolor='black', shrink=0.05))

ax.annotate('local minimum', xy=(5 * np.pi, -1), xytext=(2, -6),
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="angle3,angleA=0,angleB=-90"));

# %%
fig, ax = plt.subplots(figsize=(12, 4))
births_by_date.plot(ax=ax)

# Add labels to the plot
ax.annotate("New Year's Day", xy=('2012-1-1', 4100),  xycoords='data',
            xytext=(50, -30), textcoords='offset points',
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="arc3,rad=-0.2"))

ax.annotate("Independence Day", xy=('2012-7-4', 4250),  xycoords='data',
            bbox=dict(boxstyle="round", fc="none", ec="gray"),
            xytext=(10, -40), textcoords='offset points', ha='center',
            arrowprops=dict(arrowstyle="->"))

ax.annotate('Labor Day', xy=('2012-9-4', 4850), xycoords='data', ha='center',
            xytext=(0, -20), textcoords='offset points')
ax.annotate('', xy=('2012-9-1', 4850), xytext=('2012-9-7', 4850),
            xycoords='data', textcoords='data',
            arrowprops={'arrowstyle': '|-|,widthA=0.2,widthB=0.2', })

ax.annotate('Halloween', xy=('2012-10-31', 4600),  xycoords='data',
            xytext=(-80, -40), textcoords='offset points',
            arrowprops=dict(arrowstyle="fancy",
                            fc="0.6", ec="none",
                            connectionstyle="angle3,angleA=0,angleB=-90"))

ax.annotate('Thanksgiving', xy=('2012-11-25', 4500),  xycoords='data',
            xytext=(-120, -60), textcoords='offset points',
            bbox=dict(boxstyle="round4,pad=.5", fc="0.9"),
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="angle,angleA=0,angleB=80,rad=20"))


ax.annotate('Christmas', xy=('2012-12-25', 3850),  xycoords='data',
             xytext=(-30, 0), textcoords='offset points',
             size=13, ha='right', va="center",
             bbox=dict(boxstyle="round", alpha=0.1),
             arrowprops=dict(arrowstyle="wedge,tail_width=0.5", alpha=0.1));

# Label the axes
ax.set(title='USA births by day of year (1969-1988)',
       ylabel='average daily births')

# Format the x axis with centered month labels
ax.xaxis.set_major_locator(mpl.dates.MonthLocator())
ax.xaxis.set_minor_locator(mpl.dates.MonthLocator(bymonthday=15))
ax.xaxis.set_major_formatter(plt.NullFormatter())
ax.xaxis.set_minor_formatter(mpl.dates.DateFormatter('%h'));

ax.set_ylim(3600, 5400);
# Out:
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x00000229D39AF550> (for post_execute):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\pyton38\lib\site-packages\matplotlib\axis.py:1520, in Axis.convert_units(self, x)
#    1519 try:
# -> 1520     ret = self.converter.convert(x, self.units, self)
#    1521 except Exception as e:
#
# File c:\pyton38\lib\site-packages\matplotlib\category.py:49, in StrCategoryConverter.convert(value, unit, axis)
#      48 if unit is None:
# ---> 49     raise ValueError(
#      50         'Missing category information for StrCategoryConverter; '
#      51         'this might be caused by unintendedly mixing categorical and '
#      52         'numeric data')
#      53 # dtype = object preserves numerical pass throughs
#
# ValueError: Missing category information for StrCategoryConverter; this might be caused by unintendedly mixing categorical and numeric data
#
# The above exception was the direct cause of the following exception:
#
# ConversionError                           Traceback (most recent call last)
# File c:\pyton38\lib\site-packages\matplotlib\pyplot.py:138, in install_repl_displayhook.<locals>.post_execute()
#     136 def post_execute():
#     137     if matplotlib.is_interactive():
# --> 138         draw_all()
#
# File c:\pyton38\lib\site-packages\matplotlib\_pylab_helpers.py:138, in Gcf.draw_all(cls, force)
#     136 for manager in cls.get_all_fig_managers():
#     137     if force or manager.canvas.figure.stale:
# --> 138         manager.canvas.draw_idle()
#
# File c:\pyton38\lib\site-packages\matplotlib\backend_bases.py:2012, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    2010 if not self._is_idle_drawing:
#    2011     with self._idle_draw_cntx():
# -> 2012         self.draw(*args, **kwargs)
#
# File c:\pyton38\lib\site-packages\matplotlib\backends\backend_agg.py:407, in FigureCanvasAgg.draw(self)
#     403 # Acquire a lock on the shared font cache.
#     404 with RendererAgg.lock, \
#     405      (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     406       else nullcontext()):
# --> 407     self.figure.draw(self.renderer)
#     408     # A GUI class may be need to update a window using this draw, so
#     409     # don't forget to call the superclass.
#     410     super().draw()
#
# File c:\pyton38\lib\site-packages\matplotlib\artist.py:41, in allow_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      38     if artist.get_agg_filter() is not None:
#      39         renderer.start_filter()
# ---> 41     return draw(artist, renderer, *args, **kwargs)
#      42 finally:
#      43     if artist.get_agg_filter() is not None:
#
# File c:\pyton38\lib\site-packages\matplotlib\figure.py:1863, in Figure.draw(self, renderer)
#    1860             # ValueError can occur when resizing a window.
#    1862     self.patch.draw(renderer)
# -> 1863     mimage._draw_list_compositing_images(
#    1864         renderer, self, artists, self.suppressComposite)
#    1866     renderer.close_group('figure')
#    1867 finally:
#
# File c:\pyton38\lib\site-packages\matplotlib\image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File c:\pyton38\lib\site-packages\matplotlib\artist.py:41, in allow_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      38     if artist.get_agg_filter() is not None:
#      39         renderer.start_filter()
# ---> 41     return draw(artist, renderer, *args, **kwargs)
#      42 finally:
#      43     if artist.get_agg_filter() is not None:
#
# File c:\pyton38\lib\site-packages\matplotlib\cbook\deprecation.py:411, in _delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     401     deprecation_addendum = (
#     402         f"If any parameter follows {name!r}, they should be passed as "
#     403         f"keyword, not positionally.")
#     404     warn_deprecated(
#     405         since,
#     406         name=repr(name),
#    (...)
#     409                  else deprecation_addendum,
#     410         **kwargs)
# --> 411 return func(*inner_args, **inner_kwargs)
#
# File c:\pyton38\lib\site-packages\matplotlib\axes\_base.py:2747, in _AxesBase.draw(self, renderer, inframe)
#    2744         a.draw(renderer)
#    2745     renderer.stop_rasterizing()
# -> 2747 mimage._draw_list_compositing_images(renderer, self, artists)
#    2749 renderer.close_group('axes')
#    2750 self.stale = False
#
# File c:\pyton38\lib\site-packages\matplotlib\image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File c:\pyton38\lib\site-packages\matplotlib\artist.py:41, in allow_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      38     if artist.get_agg_filter() is not None:
#      39         renderer.start_filter()
# ---> 41     return draw(artist, renderer, *args, **kwargs)
#      42 finally:
#      43     if artist.get_agg_filter() is not None:
#
# File c:\pyton38\lib\site-packages\matplotlib\text.py:1888, in Annotation.draw(self, renderer)
#    1886 if renderer is not None:
#    1887     self._renderer = renderer
# -> 1888 if not self.get_visible() or not self._check_xy(renderer):
#    1889     return
#    1890 self.update_positions(renderer)
#
# File c:\pyton38\lib\site-packages\matplotlib\text.py:1483, in _AnnotationBase._check_xy(self, renderer)
#    1480 b = self.get_annotation_clip()
#    1481 if b or (b is None and self.xycoords == "data"):
#    1482     # check if self.xy is inside the axes.
# -> 1483     xy_pixel = self._get_position_xy(renderer)
#    1484     return self.axes.contains_point(xy_pixel)
#    1485 return True
#
# File c:\pyton38\lib\site-packages\matplotlib\text.py:1476, in _AnnotationBase._get_position_xy(self, renderer)
#    1474 """Return the pixel position of the annotated point."""
#    1475 x, y = self.xy
# -> 1476 return self._get_xy(renderer, x, y, self.xycoords)
#
# File c:\pyton38\lib\site-packages\matplotlib\text.py:1344, in _AnnotationBase._get_xy(self, renderer, x, y, s)
#    1342     s1, s2 = s, s
#    1343 if s1 == 'data':
# -> 1344     x = float(self.convert_xunits(x))
#    1345 if s2 == 'data':
#    1346     y = float(self.convert_yunits(y))
#
# File c:\pyton38\lib\site-packages\matplotlib\artist.py:175, in Artist.convert_xunits(self, x)
#     173 if ax is None or ax.xaxis is None:
#     174     return x
# --> 175 return ax.xaxis.convert_units(x)
#
# File c:\pyton38\lib\site-packages\matplotlib\axis.py:1522, in Axis.convert_units(self, x)
#    1520     ret = self.converter.convert(x, self.units, self)
#    1521 except Exception as e:
# -> 1522     raise munits.ConversionError('Failed to convert value(s) to axis '
#    1523                                  f'units: {x!r}') from e
#    1524 return ret
#
# ConversionError: Failed to convert value(s) to axis units: '2012-1-1'
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\pyton38\lib\site-packages\matplotlib\axis.py:1520, in Axis.convert_units(self, x)
#    1519 try:
# -> 1520     ret = self.converter.convert(x, self.units, self)
#    1521 except Exception as e:
#
# File c:\pyton38\lib\site-packages\matplotlib\category.py:49, in StrCategoryConverter.convert(value, unit, axis)
#      48 if unit is None:
# ---> 49     raise ValueError(
#      50         'Missing category information for StrCategoryConverter; '
#      51         'this might be caused by unintendedly mixing categorical and '
#      52         'numeric data')
#      53 # dtype = object preserves numerical pass throughs
#
# ValueError: Missing category information for StrCategoryConverter; this might be caused by unintendedly mixing categorical and numeric data
#
# The above exception was the direct cause of the following exception:
#
# ConversionError                           Traceback (most recent call last)
# File c:\pyton38\lib\site-packages\IPython\core\formatters.py:340, in BaseFormatter.__call__(self, obj)
#     338     pass
#     339 else:
# --> 340     return printer(obj)
#     341 # Finally look for special method names
#     342 method = get_real_method(obj, self.print_method)
#
# File c:\pyton38\lib\site-packages\IPython\core\pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File c:\pyton38\lib\site-packages\matplotlib\backend_bases.py:2193, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2189 ctx = (renderer._draw_disabled()
#    2190        if hasattr(renderer, '_draw_disabled')
#    2191        else suppress())
#    2192 with ctx:
# -> 2193     self.figure.draw(renderer)
#    2195 bbox_inches = self.figure.get_tightbbox(
#    2196     renderer, bbox_extra_artists=bbox_extra_artists)
#    2197 if pad_inches is None:
#
# File c:\pyton38\lib\site-packages\matplotlib\artist.py:41, in allow_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      38     if artist.get_agg_filter() is not None:
#      39         renderer.start_filter()
# ---> 41     return draw(artist, renderer, *args, **kwargs)
#      42 finally:
#      43     if artist.get_agg_filter() is not None:
#
# File c:\pyton38\lib\site-packages\matplotlib\figure.py:1863, in Figure.draw(self, renderer)
#    1860             # ValueError can occur when resizing a window.
#    1862     self.patch.draw(renderer)
# -> 1863     mimage._draw_list_compositing_images(
#    1864         renderer, self, artists, self.suppressComposite)
#    1866     renderer.close_group('figure')
#    1867 finally:
#
# File c:\pyton38\lib\site-packages\matplotlib\image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File c:\pyton38\lib\site-packages\matplotlib\artist.py:41, in allow_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      38     if artist.get_agg_filter() is not None:
#      39         renderer.start_filter()
# ---> 41     return draw(artist, renderer, *args, **kwargs)
#      42 finally:
#      43     if artist.get_agg_filter() is not None:
#
# File c:\pyton38\lib\site-packages\matplotlib\cbook\deprecation.py:411, in _delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     401     deprecation_addendum = (
#     402         f"If any parameter follows {name!r}, they should be passed as "
#     403         f"keyword, not positionally.")
#     404     warn_deprecated(
#     405         since,
#     406         name=repr(name),
#    (...)
#     409                  else deprecation_addendum,
#     410         **kwargs)
# --> 411 return func(*inner_args, **inner_kwargs)
#
# File c:\pyton38\lib\site-packages\matplotlib\axes\_base.py:2747, in _AxesBase.draw(self, renderer, inframe)
#    2744         a.draw(renderer)
#    2745     renderer.stop_rasterizing()
# -> 2747 mimage._draw_list_compositing_images(renderer, self, artists)
#    2749 renderer.close_group('axes')
#    2750 self.stale = False
#
# File c:\pyton38\lib\site-packages\matplotlib\image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File c:\pyton38\lib\site-packages\matplotlib\artist.py:41, in allow_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      38     if artist.get_agg_filter() is not None:
#      39         renderer.start_filter()
# ---> 41     return draw(artist, renderer, *args, **kwargs)
#      42 finally:
#      43     if artist.get_agg_filter() is not None:
#
# File c:\pyton38\lib\site-packages\matplotlib\text.py:1888, in Annotation.draw(self, renderer)
#    1886 if renderer is not None:
#    1887     self._renderer = renderer
# -> 1888 if not self.get_visible() or not self._check_xy(renderer):
#    1889     return
#    1890 self.update_positions(renderer)
#
# File c:\pyton38\lib\site-packages\matplotlib\text.py:1483, in _AnnotationBase._check_xy(self, renderer)
#    1480 b = self.get_annotation_clip()
#    1481 if b or (b is None and self.xycoords == "data"):
#    1482     # check if self.xy is inside the axes.
# -> 1483     xy_pixel = self._get_position_xy(renderer)
#    1484     return self.axes.contains_point(xy_pixel)
#    1485 return True
#
# File c:\pyton38\lib\site-packages\matplotlib\text.py:1476, in _AnnotationBase._get_position_xy(self, renderer)
#    1474 """Return the pixel position of the annotated point."""
#    1475 x, y = self.xy
# -> 1476 return self._get_xy(renderer, x, y, self.xycoords)
#
# File c:\pyton38\lib\site-packages\matplotlib\text.py:1344, in _AnnotationBase._get_xy(self, renderer, x, y, s)
#    1342     s1, s2 = s, s
#    1343 if s1 == 'data':
# -> 1344     x = float(self.convert_xunits(x))
#    1345 if s2 == 'data':
#    1346     y = float(self.convert_yunits(y))
#
# File c:\pyton38\lib\site-packages\matplotlib\artist.py:175, in Artist.convert_xunits(self, x)
#     173 if ax is None or ax.xaxis is None:
#     174     return x
# --> 175 return ax.xaxis.convert_units(x)
#
# File c:\pyton38\lib\site-packages\matplotlib\axis.py:1522, in Axis.convert_units(self, x)
#    1520     ret = self.converter.convert(x, self.units, self)
#    1521 except Exception as e:
# -> 1522     raise munits.ConversionError('Failed to convert value(s) to axis '
#    1523                                  f'units: {x!r}') from e
#    1524 return ret
#
# ConversionError: Failed to convert value(s) to axis units: '2012-1-1'
